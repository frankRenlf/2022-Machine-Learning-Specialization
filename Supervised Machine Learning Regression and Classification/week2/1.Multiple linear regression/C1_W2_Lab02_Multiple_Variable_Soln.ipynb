# %% [markdown]
# # Optional Lab: Multiple Variable Linear Regression
#
# In this lab, you will extend the data structures and previously developed routines to support multiple features. Several routines are updated making the lab appear lengthy, but it makes minor adjustments to previous routines making it quick to review.
# # Outline
# - [&nbsp;&nbsp;1.1 Goals](#toc_15456_1.1)
# - [&nbsp;&nbsp;1.2 Tools](#toc_15456_1.2)
# - [&nbsp;&nbsp;1.3 Notation](#toc_15456_1.3)
# - [2 Problem Statement](#toc_15456_2)
# - [&nbsp;&nbsp;2.1 Matrix X containing our examples](#toc_15456_2.1)
# - [&nbsp;&nbsp;2.2 Parameter vector w, b](#toc_15456_2.2)
# - [3 Model Prediction With Multiple Variables](#toc_15456_3)
# - [&nbsp;&nbsp;3.1 Single Prediction element by element](#toc_15456_3.1)
# - [&nbsp;&nbsp;3.2 Single Prediction, vector](#toc_15456_3.2)
# - [4 Compute Cost With Multiple Variables](#toc_15456_4)
# - [5 Gradient Descent With Multiple Variables](#toc_15456_5)
# - [&nbsp;&nbsp;5.1 Compute Gradient with Multiple Variables](#toc_15456_5.1)
# - [&nbsp;&nbsp;5.2 Gradient Descent With Multiple Variables](#toc_15456_5.2)
# - [6 Congratulations](#toc_15456_6)

# %% [markdown]
# <a name="toc_15456_1.1"></a>
# ## 1.1 Goals
# - Extend our regression model  routines to support multiple features
#     - Extend data structures to support multiple features
#     - Rewrite prediction, cost and gradient routines to support multiple features
#     - Utilize NumPy `np.dot` to vectorize their implementations for speed and simplicity

# %% [markdown]
# <a name="toc_15456_1.2"></a>
# ## 1.2 Tools
# In this lab, we will make use of:
# - NumPy, a popular library for scientific computing
# - Matplotlib, a popular library for plotting data

# %%
import copy, math
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')
np.set_printoptions(precision=2)  # reduced display precision on numpy arrays

# %% [markdown]
# <a name="toc_15456_1.3"></a>
# ## 1.3 Notation
# Here is a summary of some of the notation you will encounter, updated for multiple features.
#
# |General <img width=70/> <br />  Notation  <img width=70/> | Description<img width=350/>| Python (if applicable) |
# |: ------------|: ------------------------------------------------------------||
# | $a$ | scalar, non bold                                                      ||
# | $\mathbf{a}$ | vector, bold                                                 ||
# | $\mathbf{A}$ | matrix, bold capital                                         ||
# | **Regression** |         |    |     |
# |  $\mathbf{X}$ | training example maxtrix                  | `X_train` |
# |  $\mathbf{y}$  | training example  targets                | `y_train`
# |  $\mathbf{x}^{(i)}$, $y^{(i)}$ | $i_{th}$Training Example | `X[i]`, `y[i]`|
# | m | number of training examples | `m`|
# | n | number of features in each example | `n`|
# |  $\mathbf{w}$  |  parameter: weight,                       | `w`    |
# |  $b$           |  parameter: bias                                           | `b`    |
# | $f_{\mathbf{w},b}(\mathbf{x}^{(i)})$ | The result of the model evaluation at $\mathbf{x^{(i)}}$ parameterized by $\mathbf{w},b$: $f_{\mathbf{w},b}(\mathbf{x}^{(i)}) = \mathbf{w} \cdot \mathbf{x}^{(i)}+b$  | `f_wb` |

# %% [markdown]
# <a name="toc_15456_2"></a>
# # 2 Problem Statement
#
# You will use the motivating example of housing price prediction. The training dataset contains three examples with four features (size, bedrooms, floors and, age) shown in the table below.  Note that, unlike the earlier labs, size is in sqft rather than 1000 sqft. This causes an issue, which you will solve in the next lab!
#
# | Size (sqft) | Number of Bedrooms  | Number of floors | Age of  Home | Price (1000s dollars)  |
# | ----------------| ------------------- |----------------- |--------------|-------------- |
# | 2104            | 5                   | 1                | 45           | 460           |
# | 1416            | 3                   | 2                | 40           | 232           |
# | 852             | 2                   | 1                | 35           | 178           |
#
# You will build a linear regression model using these values, so you can then predict the price for other houses. For example, a house with 1200 sqft, 3 bedrooms, 1 floor, 40 years old.
#
# Please run the following code cell to create your `X_train` and `y_train` variables.

# %%
X_train = np.array([[2104, 5, 1, 45], [1416, 3, 2, 40], [852, 2, 1, 35]])
y_train = np.array([460, 232, 178])

# %% [markdown]
# <a name="toc_15456_2.1"></a>
# ## 2.1 Matrix X containing our examples
# Similar to the table above, examples are stored in a NumPy matrix `X_train`. Each row of the matrix represents one example. When you have $m$ training examples ( $m$ is three in our example), and there are $n$ features (four in our example), $\mathbf{X}$ is a matrix with dimensions ($m$, $n$) (m rows, n columns).
#
#
# $$\mathbf{X} =
# \begin{pmatrix}
#  x^{(0)}_0 & x^{(0)}_1 & \cdots & x^{(0)}_{n-1} \\
#  x^{(1)}_0 & x^{(1)}_1 & \cdots & x^{(1)}_{n-1} \\
#  \cdots \\
#  x^{(m-1)}_0 & x^{(m-1)}_1 & \cdots & x^{(m-1)}_{n-1}
# \end{pmatrix}
# $$
# notation:
# - $\mathbf{x}^{(i)}$ is vector containing example i. $\mathbf{x}^{(i)}$ $ = (x^{(i)}_0, x^{(i)}_1, \cdots,x^{(i)}_{n-1})$
# - $x^{(i)}_j$ is element j in example i. The superscript in parenthesis indicates the example number while the subscript represents an element.
#
# Display the input data.

# %%
# data is stored in numpy array/matrix
print(f"X Shape: {X_train.shape}, X Type:{type(X_train)})")
print(X_train)
print(f"y Shape: {y_train.shape}, y Type:{type(y_train)})")
print(y_train)
# Out:
# X Shape: (3, 4), X Type:<class 'numpy.ndarray'>)
# [[2104    5    1   45]
#  [1416    3    2   40]
#  [ 852    2    1   35]]
# y Shape: (3,), y Type:<class 'numpy.ndarray'>)
# [460 232 178]

# %% [markdown]
# <a name="toc_15456_2.2"></a>
# ## 2.2 Parameter vector w, b
#
# * $\mathbf{w}$ is a vector with $n$ elements.
#   - Each element contains the parameter associated with one feature.
#   - in our dataset, n is 4.
#   - notionally, we draw this as a column vector
#
# $$\mathbf{w} = \begin{pmatrix}
# w_0 \\
# w_1 \\
# \cdots\\
# w_{n-1}
# \end{pmatrix}
# $$
# * $b$ is a scalar parameter.

# %% [markdown]
# For demonstration, $\mathbf{w}$ and $b$ will be loaded with some initial selected values that are near the optimal. $\mathbf{w}$ is a 1-D NumPy vector.

# %%
b_init = 785.1811367994083
w_init = np.array([ 0.39133535, 18.75376741, -53.36032453, -26.42131618])
print(f"w_init shape: {w_init.shape}, b_init type: {type(b_init)}")
# Out:
# w_init shape: (4,), b_init type: <class 'float'>

# %% [markdown]
# <a name="toc_15456_3"></a>
# # 3 Model Prediction With Multiple Variables
# The model's prediction with multiple variables is given by the linear model:
#
# $$ f_{\mathbf{w},b}(\mathbf{x}) =  w_0x_0 + w_1x_1 +... + w_{n-1}x_{n-1} + b \tag{1}$$
# or in vector notation:
# $$ f_{\mathbf{w},b}(\mathbf{x}) = \mathbf{w} \cdot \mathbf{x} + b  \tag{2} $$
# where $\cdot$ is a vector `dot product`
#
# To demonstrate the dot product, we will implement prediction using (1) and (2).

# %% [markdown]
# <a name="toc_15456_3.1"></a>
# ## 3.1 Single Prediction element by element
# Our previous prediction multiplied one feature value by one parameter and added a bias parameter. A direct extension of our previous implementation of prediction to multiple features would be to implement (1) above using loop over each element, performing the multiply with its parameter and then adding the bias parameter at the end.

# %%
def predict_single_loop(x, w, b): 
    """
    single predict using linear regression
    
    Args:
      x (ndarray): Shape (n,) example with multiple features
      w (ndarray): Shape (n,) model parameters    
      b (scalar):  model parameter     
      
    Returns:
      p (scalar):  prediction
    """
    n = x.shape[0]
    p = 0
    for i in range(n):
        p_i = x[i] * w[i]  
        p = p + p_i         
    p = p + b                
    return p

# %%
# get a row from our training data
x_vec = X_train[0,:]
print(f"x_vec shape {x_vec.shape}, x_vec value: {x_vec}")

# make a prediction
f_wb = predict_single_loop(x_vec, w_init, b_init)
print(f"f_wb shape {f_wb.shape}, prediction: {f_wb}")
# Out:
# x_vec shape (4,), x_vec value: [2104    5    1   45]
# f_wb shape (), prediction: 459.9999976194083

# %% [markdown]
# Note the shape of `x_vec`. It is a 1-D NumPy vector with 4 elements, (4,). The result, `f_wb` is a scalar.

# %% [markdown]
# <a name="toc_15456_3.2"></a>
# ## 3.2 Single Prediction, vector
#
# Noting that equation (1) above can be implemented using the dot product as in (2) above. We can make use of vector operations to speed up predictions.
#
# Recall from the Python/Numpy lab that NumPy `np.dot()`[[link](https://numpy.org/doc/stable/reference/generated/numpy.dot.html)] can be used to perform a vector dot product.

# %%
def predict(x, w, b): 
    """
    single predict using linear regression
    Args:
      x (ndarray): Shape (n,) example with multiple features
      w (ndarray): Shape (n,) model parameters   
      b (scalar):             model parameter 
      
    Returns:
      p (scalar):  prediction
    """
    p = np.dot(x, w) + b     
    return p

# %%
# get a row from our training data
x_vec = X_train[0,:]
print(f"x_vec shape {x_vec.shape}, x_vec value: {x_vec}")

# make a prediction
f_wb = predict(x_vec,w_init, b_init)
print(f"f_wb shape {f_wb.shape}, prediction: {f_wb}")
# Out:
# x_vec shape (4,), x_vec value: [2104    5    1   45]
# f_wb shape (), prediction: 459.9999976194083

# %% [markdown]
# The results and shapes are the same as the previous version which used looping. Going forward, `np.dot` will be used for these operations. The prediction is now a single statement. Most routines will implement it directly rather than calling a separate predict routine.

# %% [markdown]
# <a name="toc_15456_4"></a>
# # 4 Compute Cost With Multiple Variables
# The equation for the cost function with multiple variables $J(\mathbf{w},b)$ is:
# $$J(\mathbf{w},b) = \frac{1}{2m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - y^{(i)})^2 \tag{3}$$
# where:
# $$ f_{\mathbf{w},b}(\mathbf{x}^{(i)}) = \mathbf{w} \cdot \mathbf{x}^{(i)} + b  \tag{4} $$
#
#
# In contrast to previous labs, $\mathbf{w}$ and $\mathbf{x}^{(i)}$ are vectors rather than scalars supporting multiple features.

# %% [markdown]
# Below is an implementation of equations (3) and (4). Note that this uses a *standard pattern for this course* where a for loop over all `m` examples is used.

# %%
def compute_cost(X, y, w, b): 
    """
    compute cost
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters  
      b (scalar)       : model parameter
      
    Returns:
      cost (scalar): cost
    """
    m = X.shape[0]
    cost = 0.0
    for i in range(m):                                
        f_wb_i = np.dot(X[i], w) + b           #(n,)(n,) = scalar (see np.dot)
        cost += (f_wb_i - y[i])**2       #scalar
    cost = cost / (2 * m)                      #scalar    
    return cost

# %%
# Compute and display cost using our pre-chosen optimal parameters. 
cost = compute_cost(X_train, y_train, w_init, b_init)
print(f'Cost at optimal w : {cost}')
# Out:
# Cost at optimal w : 1.5578904428966628e-12

# %% [markdown]
# **Expected Result**: Cost at optimal w : 1.5578904045996674e-12

# %% [markdown]
# <a name="toc_15456_5"></a>
# # 5 Gradient Descent With Multiple Variables
# Gradient descent for multiple variables:
#
# $$\begin{align*} \text{repeat}&\text{ until convergence:} \; \lbrace \newline\;
# & w_j = w_j -  \alpha \frac{\partial J(\mathbf{w},b)}{\partial w_j} \tag{5}  \; & \text{for j = 0..n-1}\newline
# &b\ \ = b -  \alpha \frac{\partial J(\mathbf{w},b)}{\partial b}  \newline \rbrace
# \end{align*}$$
#
# where, n is the number of features, parameters $w_j$,  $b$, are updated simultaneously and where
#
# $$
# \begin{align}
# \frac{\partial J(\mathbf{w},b)}{\partial w_j}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - y^{(i)})x_{j}^{(i)} \tag{6}  \\
# \frac{\partial J(\mathbf{w},b)}{\partial b}  &= \frac{1}{m} \sum\limits_{i = 0}^{m-1} (f_{\mathbf{w},b}(\mathbf{x}^{(i)}) - y^{(i)}) \tag{7}
# \end{align}
# $$
# * m is the number of training examples in the data set
#
#
# *  $f_{\mathbf{w},b}(\mathbf{x}^{(i)})$ is the model's prediction, while $y^{(i)}$ is the target value

# %% [markdown]
# <a name="toc_15456_5.1"></a>
# ## 5.1 Compute Gradient with Multiple Variables
# An implementation for calculating the equations (6) and (7) is below. There are many ways to implement this. In this version, there is an
# - outer loop over all m examples.
#     - $\frac{\partial J(\mathbf{w},b)}{\partial b}$ for the example can be computed directly and accumulated
#     - in a second loop over all n features:
#         - $\frac{\partial J(\mathbf{w},b)}{\partial w_j}$ is computed for each $w_j$.

# %%
def compute_gradient(X, y, w, b): 
    """
    Computes the gradient for linear regression 
    Args:
      X (ndarray (m,n)): Data, m examples with n features
      y (ndarray (m,)) : target values
      w (ndarray (n,)) : model parameters  
      b (scalar)       : model parameter
      
    Returns:
      dj_dw (ndarray (n,)): The gradient of the cost w.r.t. the parameters w. 
      dj_db (scalar):       The gradient of the cost w.r.t. the parameter b. 
    """
    m,n = X.shape           #(number of examples, number of features)
    dj_dw = np.zeros((n,))
    dj_db = 0.

    for i in range(m):                             
        sub = (np.dot(X[i], w) + b) - y[i]
        for j in range(n):                         
            dj_dw[j] = dj_dw[j] + sub * X[i, j]
        dj_db = dj_db + sub
    dj_dw = dj_dw / m                                
    dj_db = dj_db / m                                
        
    return dj_db, dj_dw

# %%
#Compute and display gradient 
tmp_dj_db, tmp_dj_dw = compute_gradient(X_train, y_train, w_init, b_init)
print(f'dj_db at initial w,b: {tmp_dj_db}')
print(f'dj_dw at initial w,b: \n {tmp_dj_dw}')
# Out:
# dj_db at initial w,b: -1.6739251501955248e-06
# dj_dw at initial w,b:
#  [-2.73e-03 -6.27e-06 -2.22e-06 -6.92e-05]

# %% [markdown]
# **Expected Result**:
# dj_db at initial w,b: -1.6739251122999121e-06
# dj_dw at initial w,b:
#  [-2.73e-03 -6.27e-06 -2.22e-06 -6.92e-05]

# %% [markdown]
# <a name="toc_15456_5.2"></a>
# ## 5.2 Gradient Descent With Multiple Variables
# The routine below implements equation (5) above.

# %%
def gradient_descent(X, y, w_in, b_in, cost_function, gradient_function, alpha, num_iters): 
    """
    Performs batch gradient descent to learn theta. Updates theta by taking 
    num_iters gradient steps with learning rate alpha
    
    Args:
      X (ndarray (m,n))   : Data, m examples with n features
      y (ndarray (m,))    : target values
      w_in (ndarray (n,)) : initial model parameters  
      b_in (scalar)       : initial model parameter
      cost_function       : function to compute cost
      gradient_function   : function to compute the gradient
      alpha (float)       : Learning rate
      num_iters (int)     : number of iterations to run gradient descent
      
    Returns:
      w (ndarray (n,)) : Updated values of parameters 
      b (scalar)       : Updated value of parameter 
      """
    
    # An array to store cost J and w's at each iteration primarily for graphing later
    J_history = []
    w = copy.deepcopy(w_in)  #avoid modifying global w within function
    b = b_in
    
    for i in range(num_iters):

        # Calculate the gradient and update the parameters
        dj_db,dj_dw = gradient_function(X, y, w, b)   ##None

        # Update Parameters using w, b, alpha and gradient
        w = w - alpha * dj_dw               ##None
        b = b - alpha * dj_db               ##None
      
        # Save cost J at each iteration
        if i<100000:      # prevent resource exhaustion 
            J_history.append( cost_function(X, y, w, b))

        # Print cost every at intervals 10 times or as many iterations if < 10
        if i% math.ceil(num_iters / 10) == 0:
            print(f"Iteration {i:4d}: Cost {J_history[-1]:8.2f}   ")
        
    return w, b, J_history #return final w,b and J history for graphing

# %% [markdown]
# In the next cell you will test the implementation.

# %%
# initialize parameters
initial_w = np.zeros_like(w_init)
initial_b = 0.
# some gradient descent settings
iterations = 1000
alpha = 5.0e-7
# run gradient descent 
w_final, b_final, J_hist = gradient_descent(X_train, y_train, initial_w, initial_b,
                                                    compute_cost, compute_gradient, 
                                                    alpha, iterations)
print(f"b,w found by gradient descent: {b_final:0.2f},{w_final} ")
m,_ = X_train.shape
for i in range(m):
    print(f"prediction: {np.dot(X_train[i], w_final) + b_final:0.2f}, target value: {y_train[i]}")
# Out:
# Iteration    0: Cost  2529.46
# Iteration    1: Cost   765.83
# Iteration    2: Cost   699.63
# Iteration    3: Cost   697.13
# Iteration    4: Cost   697.03
# Iteration    5: Cost   697.02
# Iteration    6: Cost   697.00
# Iteration    7: Cost   696.99
# Iteration    8: Cost   696.98
# Iteration    9: Cost   696.97
# Iteration   10: Cost   696.96
# Iteration   11: Cost   696.95
# Iteration   12: Cost   696.94
# Iteration   13: Cost   696.93
# Iteration   14: Cost   696.92
# Iteration   15: Cost   696.91
# Iteration   16: Cost   696.90
# Iteration   17: Cost   696.89
# Iteration   18: Cost   696.87
# Iteration   19: Cost   696.86
# Iteration   20: Cost   696.85
# Iteration   21: Cost   696.84
# Iteration   22: Cost   696.83
# Iteration   23: Cost   696.82
# Iteration   24: Cost   696.81
# Iteration   25: Cost   696.80
# Iteration   26: Cost   696.79
# Iteration   27: Cost   696.78
# Iteration   28: Cost   696.77
# Iteration   29: Cost   696.76
# Iteration   30: Cost   696.74
# Iteration   31: Cost   696.73
# Iteration   32: Cost   696.72
# Iteration   33: Cost   696.71
# Iteration   34: Cost   696.70
# Iteration   35: Cost   696.69
# Iteration   36: Cost   696.68
# Iteration   37: Cost   696.67
# Iteration   38: Cost   696.66
# Iteration   39: Cost   696.65
# Iteration   40: Cost   696.64
# Iteration   41: Cost   696.63
# Iteration   42: Cost   696.62
# Iteration   43: Cost   696.60
# Iteration   44: Cost   696.59
# Iteration   45: Cost   696.58
# Iteration   46: Cost   696.57
# Iteration   47: Cost   696.56
# Iteration   48: Cost   696.55
# Iteration   49: Cost   696.54
# Iteration   50: Cost   696.53
# Iteration   51: Cost   696.52
# Iteration   52: Cost   696.51
# Iteration   53: Cost   696.50
# Iteration   54: Cost   696.49
# Iteration   55: Cost   696.47
# Iteration   56: Cost   696.46
# Iteration   57: Cost   696.45
# Iteration   58: Cost   696.44
# Iteration   59: Cost   696.43
# Iteration   60: Cost   696.42
# Iteration   61: Cost   696.41
# Iteration   62: Cost   696.40
# Iteration   63: Cost   696.39
# Iteration   64: Cost   696.38
# Iteration   65: Cost   696.37
# Iteration   66: Cost   696.36
# Iteration   67: Cost   696.35
# Iteration   68: Cost   696.33
# Iteration   69: Cost   696.32
# Iteration   70: Cost   696.31
# Iteration   71: Cost   696.30
# Iteration   72: Cost   696.29
# Iteration   73: Cost   696.28
# Iteration   74: Cost   696.27
# Iteration   75: Cost   696.26
# Iteration   76: Cost   696.25
# Iteration   77: Cost   696.24
# Iteration   78: Cost   696.23
# Iteration   79: Cost   696.22
# Iteration   80: Cost   696.21
# Iteration   81: Cost   696.19
# Iteration   82: Cost   696.18
# Iteration   83: Cost   696.17
# Iteration   84: Cost   696.16
# Iteration   85: Cost   696.15
# Iteration   86: Cost   696.14
# Iteration   87: Cost   696.13
# Iteration   88: Cost   696.12
# Iteration   89: Cost   696.11
# Iteration   90: Cost   696.10
# Iteration   91: Cost   696.09
# Iteration   92: Cost   696.08
# Iteration   93: Cost   696.07
# Iteration   94: Cost   696.05
# Iteration   95: Cost   696.04
# Iteration   96: Cost   696.03
# Iteration   97: Cost   696.02
# Iteration   98: Cost   696.01
# Iteration   99: Cost   696.00
# Iteration  100: Cost   695.99
# Iteration  101: Cost   695.98
# Iteration  102: Cost   695.97
# Iteration  103: Cost   695.96
# Iteration  104: Cost   695.95
# Iteration  105: Cost   695.94
# Iteration  106: Cost   695.93
# Iteration  107: Cost   695.92
# Iteration  108: Cost   695.90
# Iteration  109: Cost   695.89
# Iteration  110: Cost   695.88
# Iteration  111: Cost   695.87
# Iteration  112: Cost   695.86
# Iteration  113: Cost   695.85
# Iteration  114: Cost   695.84
# Iteration  115: Cost   695.83
# Iteration  116: Cost   695.82
# Iteration  117: Cost   695.81
# Iteration  118: Cost   695.80
# Iteration  119: Cost   695.79
# Iteration  120: Cost   695.78
# Iteration  121: Cost   695.76
# Iteration  122: Cost   695.75
# Iteration  123: Cost   695.74
# Iteration  124: Cost   695.73
# Iteration  125: Cost   695.72
# Iteration  126: Cost   695.71
# Iteration  127: Cost   695.70
# Iteration  128: Cost   695.69
# Iteration  129: Cost   695.68
# Iteration  130: Cost   695.67
# Iteration  131: Cost   695.66
# Iteration  132: Cost   695.65
# Iteration  133: Cost   695.64
# Iteration  134: Cost   695.63
# Iteration  135: Cost   695.61
# Iteration  136: Cost   695.60
# Iteration  137: Cost   695.59
# Iteration  138: Cost   695.58
# Iteration  139: Cost   695.57
# Iteration  140: Cost   695.56
# Iteration  141: Cost   695.55
# Iteration  142: Cost   695.54
# Iteration  143: Cost   695.53
# Iteration  144: Cost   695.52
# Iteration  145: Cost   695.51
# Iteration  146: Cost   695.50
# Iteration  147: Cost   695.49
# Iteration  148: Cost   695.48
# Iteration  149: Cost   695.47
# Iteration  150: Cost   695.45
# Iteration  151: Cost   695.44
# Iteration  152: Cost   695.43
# Iteration  153: Cost   695.42
# Iteration  154: Cost   695.41
# Iteration  155: Cost   695.40
# Iteration  156: Cost   695.39
# Iteration  157: Cost   695.38
# Iteration  158: Cost   695.37
# Iteration  159: Cost   695.36
# Iteration  160: Cost   695.35
# Iteration  161: Cost   695.34
# Iteration  162: Cost   695.33
# Iteration  163: Cost   695.32
# Iteration  164: Cost   695.30
# Iteration  165: Cost   695.29
# Iteration  166: Cost   695.28
# Iteration  167: Cost   695.27
# Iteration  168: Cost   695.26
# Iteration  169: Cost   695.25
# Iteration  170: Cost   695.24
# Iteration  171: Cost   695.23
# Iteration  172: Cost   695.22
# Iteration  173: Cost   695.21
# Iteration  174: Cost   695.20
# Iteration  175: Cost   695.19
# Iteration  176: Cost   695.18
# Iteration  177: Cost   695.17
# Iteration  178: Cost   695.16
# Iteration  179: Cost   695.14
# Iteration  180: Cost   695.13
# Iteration  181: Cost   695.12
# Iteration  182: Cost   695.11
# Iteration  183: Cost   695.10
# Iteration  184: Cost   695.09
# Iteration  185: Cost   695.08
# Iteration  186: Cost   695.07
# Iteration  187: Cost   695.06
# Iteration  188: Cost   695.05
# Iteration  189: Cost   695.04
# Iteration  190: Cost   695.03
# Iteration  191: Cost   695.02
# Iteration  192: Cost   695.01
# Iteration  193: Cost   695.00
# Iteration  194: Cost   694.98
# Iteration  195: Cost   694.97
# Iteration  196: Cost   694.96
# Iteration  197: Cost   694.95
# Iteration  198: Cost   694.94
# Iteration  199: Cost   694.93
# Iteration  200: Cost   694.92
# Iteration  201: Cost   694.91
# Iteration  202: Cost   694.90
# Iteration  203: Cost   694.89
# Iteration  204: Cost   694.88
# Iteration  205: Cost   694.87
# Iteration  206: Cost   694.86
# Iteration  207: Cost   694.85
# Iteration  208: Cost   694.84
# Iteration  209: Cost   694.82
# Iteration  210: Cost   694.81
# Iteration  211: Cost   694.80
# Iteration  212: Cost   694.79
# Iteration  213: Cost   694.78
# Iteration  214: Cost   694.77
# Iteration  215: Cost   694.76
# Iteration  216: Cost   694.75
# Iteration  217: Cost   694.74
# Iteration  218: Cost   694.73
# Iteration  219: Cost   694.72
# Iteration  220: Cost   694.71
# Iteration  221: Cost   694.70
# Iteration  222: Cost   694.69
# Iteration  223: Cost   694.68
# Iteration  224: Cost   694.67
# Iteration  225: Cost   694.65
# Iteration  226: Cost   694.64
# Iteration  227: Cost   694.63
# Iteration  228: Cost   694.62
# Iteration  229: Cost   694.61
# Iteration  230: Cost   694.60
# Iteration  231: Cost   694.59
# Iteration  232: Cost   694.58
# Iteration  233: Cost   694.57
# Iteration  234: Cost   694.56
# Iteration  235: Cost   694.55
# Iteration  236: Cost   694.54
# Iteration  237: Cost   694.53
# Iteration  238: Cost   694.52
# Iteration  239: Cost   694.51
# Iteration  240: Cost   694.50
# Iteration  241: Cost   694.48
# Iteration  242: Cost   694.47
# Iteration  243: Cost   694.46
# Iteration  244: Cost   694.45
# Iteration  245: Cost   694.44
# Iteration  246: Cost   694.43
# Iteration  247: Cost   694.42
# Iteration  248: Cost   694.41
# Iteration  249: Cost   694.40
# Iteration  250: Cost   694.39
# Iteration  251: Cost   694.38
# Iteration  252: Cost   694.37
# Iteration  253: Cost   694.36
# Iteration  254: Cost   694.35
# Iteration  255: Cost   694.34
# Iteration  256: Cost   694.33
# Iteration  257: Cost   694.32
# Iteration  258: Cost   694.30
# Iteration  259: Cost   694.29
# Iteration  260: Cost   694.28
# Iteration  261: Cost   694.27
# Iteration  262: Cost   694.26
# Iteration  263: Cost   694.25
# Iteration  649: Cost   690.23
# Iteration  650: Cost   690.22
# Iteration  651: Cost   690.21
# Iteration  652: Cost   690.20
# Iteration  653: Cost   690.19
# Iteration  654: Cost   690.18
# Iteration  655: Cost   690.17
# Iteration  656: Cost   690.16
# Iteration  657: Cost   690.15
# Iteration  658: Cost   690.14
# Iteration  659: Cost   690.13
# Iteration  660: Cost   690.12
# Iteration  661: Cost   690.11
# Iteration  662: Cost   690.10
# Iteration  663: Cost   690.09
# Iteration  664: Cost   690.08
# Iteration  665: Cost   690.07
# Iteration  666: Cost   690.06
# Iteration  667: Cost   690.05
# Iteration  668: Cost   690.04
# Iteration  669: Cost   690.03
# Iteration  670: Cost   690.02
# Iteration  671: Cost   690.01
# Iteration  672: Cost   690.00
# Iteration  673: Cost   689.99
# Iteration  674: Cost   689.98
# Iteration  675: Cost   689.97
# Iteration  676: Cost   689.96
# Iteration  677: Cost   689.95
# Iteration  678: Cost   689.94
# Iteration  679: Cost   689.93
# Iteration  680: Cost   689.92
# Iteration  681: Cost   689.91
# Iteration  682: Cost   689.89
# Iteration  683: Cost   689.88
# Iteration  684: Cost   689.87
# Iteration  685: Cost   689.86
# Iteration  686: Cost   689.85
# Iteration  687: Cost   689.84
# Iteration  688: Cost   689.83
# Iteration  689: Cost   689.82
# Iteration  690: Cost   689.81
# Iteration  691: Cost   689.80
# Iteration  692: Cost   689.79
# Iteration  693: Cost   689.78
# Iteration  694: Cost   689.77
# Iteration  695: Cost   689.76
# Iteration  696: Cost   689.75
# Iteration  697: Cost   689.74
# Iteration  698: Cost   689.73
# Iteration  699: Cost   689.72
# Iteration  700: Cost   689.71
# Iteration  701: Cost   689.70
# Iteration  702: Cost   689.69
# Iteration  703: Cost   689.68
# Iteration  704: Cost   689.67
# Iteration  705: Cost   689.66
# Iteration  706: Cost   689.65
# Iteration  707: Cost   689.64
# Iteration  708: Cost   689.63
# Iteration  709: Cost   689.62
# Iteration  710: Cost   689.61
# Iteration  711: Cost   689.60
# Iteration  712: Cost   689.59
# Iteration  713: Cost   689.58
# Iteration  714: Cost   689.57
# Iteration  715: Cost   689.56
# Iteration  716: Cost   689.55
# Iteration  717: Cost   689.54
# Iteration  718: Cost   689.53
# Iteration  719: Cost   689.52
# Iteration  720: Cost   689.51
# Iteration  721: Cost   689.50
# Iteration  722: Cost   689.49
# Iteration  723: Cost   689.48
# Iteration  724: Cost   689.47
# Iteration  725: Cost   689.46
# Iteration  726: Cost   689.45
# Iteration  727: Cost   689.44
# Iteration  728: Cost   689.43
# Iteration  729: Cost   689.42
# Iteration  730: Cost   689.41
# Iteration  731: Cost   689.40
# Iteration  732: Cost   689.39
# Iteration  733: Cost   689.38
# Iteration  734: Cost   689.37
# Iteration  735: Cost   689.36
# Iteration  736: Cost   689.34
# Iteration  737: Cost   689.33
# Iteration  738: Cost   689.32
# Iteration  739: Cost   689.31
# Iteration  740: Cost   689.30
# Iteration  741: Cost   689.29
# Iteration  742: Cost   689.28
# Iteration  743: Cost   689.27
# Iteration  744: Cost   689.26
# Iteration  745: Cost   689.25
# Iteration  746: Cost   689.24
# Iteration  747: Cost   689.23
# Iteration  748: Cost   689.22
# Iteration  749: Cost   689.21
# Iteration  750: Cost   689.20
# Iteration  751: Cost   689.19
# Iteration  752: Cost   689.18
# Iteration  753: Cost   689.17
# Iteration  754: Cost   689.16
# Iteration  755: Cost   689.15
# Iteration  756: Cost   689.14
# Iteration  757: Cost   689.13
# Iteration  758: Cost   689.12
# Iteration  759: Cost   689.11
# Iteration  760: Cost   689.10
# Iteration  761: Cost   689.09
# Iteration  762: Cost   689.08
# Iteration  763: Cost   689.07
# Iteration  764: Cost   689.06
# Iteration  765: Cost   689.05
# Iteration  766: Cost   689.04
# Iteration  767: Cost   689.03
# Iteration  768: Cost   689.02
# Iteration  769: Cost   689.01
# Iteration  770: Cost   689.00
# Iteration  771: Cost   688.99
# Iteration  772: Cost   688.98
# Iteration  773: Cost   688.97
# Iteration  774: Cost   688.96
# Iteration  775: Cost   688.95
# Iteration  776: Cost   688.94
# Iteration  777: Cost   688.93
# Iteration  778: Cost   688.92
# Iteration  779: Cost   688.91
# Iteration  780: Cost   688.90
# Iteration  781: Cost   688.89
# Iteration  782: Cost   688.88
# Iteration  783: Cost   688.87
# Iteration  784: Cost   688.86
# Iteration  785: Cost   688.85
# Iteration  786: Cost   688.84
# Iteration  787: Cost   688.83
# Iteration  788: Cost   688.82
# Iteration  789: Cost   688.81
# Iteration  790: Cost   688.80
# Iteration  791: Cost   688.79
# Iteration  792: Cost   688.78
# Iteration  793: Cost   688.77
# Iteration  794: Cost   688.76
# Iteration  795: Cost   688.75
# Iteration  796: Cost   688.74
# Iteration  797: Cost   688.73
# Iteration  798: Cost   688.72
# Iteration  799: Cost   688.71
# Iteration  800: Cost   688.70
# Iteration  801: Cost   688.69
# Iteration  802: Cost   688.68
# Iteration  803: Cost   688.67
# Iteration  804: Cost   688.66
# Iteration  805: Cost   688.65
# Iteration  806: Cost   688.64
# Iteration  807: Cost   688.63
# Iteration  808: Cost   688.62
# Iteration  809: Cost   688.61
# Iteration  810: Cost   688.60
# Iteration  811: Cost   688.59
# Iteration  812: Cost   688.58
# Iteration  813: Cost   688.57
# Iteration  814: Cost   688.56
# Iteration  815: Cost   688.55
# Iteration  816: Cost   688.53
# Iteration  817: Cost   688.52
# Iteration  818: Cost   688.51
# Iteration  819: Cost   688.50
# Iteration  820: Cost   688.49
# Iteration  821: Cost   688.48
# Iteration  822: Cost   688.47
# Iteration  823: Cost   688.46
# Iteration  824: Cost   688.45
# Iteration  825: Cost   688.44
# Iteration  826: Cost   688.43
# Iteration  827: Cost   688.42
# Iteration  828: Cost   688.41
# Iteration  829: Cost   688.40
# Iteration  830: Cost   688.39
# Iteration  831: Cost   688.38
# Iteration  832: Cost   688.37
# Iteration  833: Cost   688.36
# Iteration  834: Cost   688.35
# Iteration  835: Cost   688.34
# Iteration  836: Cost   688.33
# Iteration  837: Cost   688.32
# Iteration  838: Cost   688.31
# Iteration  839: Cost   688.30
# Iteration  840: Cost   688.29
# Iteration  841: Cost   688.28
# Iteration  842: Cost   688.27
# Iteration  843: Cost   688.26
# Iteration  844: Cost   688.25
# Iteration  845: Cost   688.24
# Iteration  846: Cost   688.23
# Iteration  847: Cost   688.22
# Iteration  848: Cost   688.21
# Iteration  849: Cost   688.20
# Iteration  850: Cost   688.19
# Iteration  851: Cost   688.18
# Iteration  852: Cost   688.17
# Iteration  853: Cost   688.16
# Iteration  854: Cost   688.15
# Iteration  855: Cost   688.14
# Iteration  856: Cost   688.13
# Iteration  857: Cost   688.12
# Iteration  858: Cost   688.11
# Iteration  859: Cost   688.10
# Iteration  860: Cost   688.09
# Iteration  861: Cost   688.08
# Iteration  862: Cost   688.07
# Iteration  863: Cost   688.06
# Iteration  864: Cost   688.05
# Iteration  865: Cost   688.04
# Iteration  866: Cost   688.03
# Iteration  867: Cost   688.02
# Iteration  868: Cost   688.01
# Iteration  869: Cost   688.00
# Iteration  870: Cost   687.99
# Iteration  871: Cost   687.98
# Iteration  872: Cost   687.97
# Iteration  873: Cost   687.96
# Iteration  874: Cost   687.95
# Iteration  875: Cost   687.94
# Iteration  876: Cost   687.93
# Iteration  877: Cost   687.92
# Iteration  878: Cost   687.91
# Iteration  879: Cost   687.90
# Iteration  880: Cost   687.89
# Iteration  881: Cost   687.88
# Iteration  882: Cost   687.87
# Iteration  883: Cost   687.86
# Iteration  884: Cost   687.85
# Iteration  885: Cost   687.84
# Iteration  886: Cost   687.83
# Iteration  887: Cost   687.82
# Iteration  888: Cost   687.81
# Iteration  889: Cost   687.80
# Iteration  890: Cost   687.79
# Iteration  891: Cost   687.78
# Iteration  892: Cost   687.77
# Iteration  893: Cost   687.76
# Iteration  894: Cost   687.75
# Iteration  895: Cost   687.74
# Iteration  896: Cost   687.73
# Iteration  897: Cost   687.72
# Iteration  898: Cost   687.71
# Iteration  899: Cost   687.70
# Iteration  900: Cost   687.69
# Iteration  901: Cost   687.68
# Iteration  902: Cost   687.67
# Iteration  903: Cost   687.66
# Iteration  904: Cost   687.65
# Iteration  905: Cost   687.64
# Iteration  906: Cost   687.63
# Iteration  907: Cost   687.62
# Iteration  908: Cost   687.61
# Iteration  909: Cost   687.60
# Iteration  910: Cost   687.59
# Iteration  911: Cost   687.58
# Iteration  912: Cost   687.57
# Iteration  913: Cost   687.56
# Iteration  914: Cost   687.55
# Iteration  915: Cost   687.54
# Iteration  916: Cost   687.53
# Iteration  917: Cost   687.52
# Iteration  918: Cost   687.51
# Iteration  919: Cost   687.50
# Iteration  920: Cost   687.49
# Iteration  921: Cost   687.48
# Iteration  922: Cost   687.47
# Iteration  923: Cost   687.46
# Iteration  924: Cost   687.45
# Iteration  925: Cost   687.44
# Iteration  926: Cost   687.43
# Iteration  927: Cost   687.42
# Iteration  928: Cost   687.41
# Iteration  929: Cost   687.40
# Iteration  930: Cost   687.39
# Iteration  931: Cost   687.38
# Iteration  932: Cost   687.37
# Iteration  933: Cost   687.36
# Iteration  934: Cost   687.35
# Iteration  935: Cost   687.34
# Iteration  936: Cost   687.33
# Iteration  937: Cost   687.32
# Iteration  938: Cost   687.31
# Iteration  939: Cost   687.30
# Iteration  940: Cost   687.29
# Iteration  941: Cost   687.28
# Iteration  942: Cost   687.27
# Iteration  943: Cost   687.26
# Iteration  944: Cost   687.25
# Iteration  945: Cost   687.24
# Iteration  946: Cost   687.23
# Iteration  947: Cost   687.22
# Iteration  948: Cost   687.21
# Iteration  949: Cost   687.20
# Iteration  950: Cost   687.19
# Iteration  951: Cost   687.18
# Iteration  952: Cost   687.17
# Iteration  953: Cost   687.16
# Iteration  954: Cost   687.15
# Iteration  955: Cost   687.14
# Iteration  956: Cost   687.13
# Iteration  957: Cost   687.12
# Iteration  958: Cost   687.11
# Iteration  959: Cost   687.10
# Iteration  960: Cost   687.09
# Iteration  961: Cost   687.08
# Iteration  962: Cost   687.07
# Iteration  963: Cost   687.06
# Iteration  964: Cost   687.05
# Iteration  965: Cost   687.04
# Iteration  966: Cost   687.03
# Iteration  967: Cost   687.02
# Iteration  968: Cost   687.01
# Iteration  969: Cost   687.00
# Iteration  970: Cost   686.99
# Iteration  971: Cost   686.98
# Iteration  972: Cost   686.97
# Iteration  973: Cost   686.96
# Iteration  974: Cost   686.95
# Iteration  975: Cost   686.94
# Iteration  976: Cost   686.93
# Iteration  977: Cost   686.92
# Iteration  978: Cost   686.91
# Iteration  979: Cost   686.90
# Iteration  980: Cost   686.89
# Iteration  981: Cost   686.88
# Iteration  982: Cost   686.87
# Iteration  983: Cost   686.86
# Iteration  984: Cost   686.85
# Iteration  985: Cost   686.84
# Iteration  986: Cost   686.83
# Iteration  987: Cost   686.82
# Iteration  988: Cost   686.81
# Iteration  989: Cost   686.80
# Iteration  990: Cost   686.79
# Iteration  991: Cost   686.78
# Iteration  992: Cost   686.77
# Iteration  993: Cost   686.76
# Iteration  994: Cost   686.75
# Iteration  995: Cost   686.74
# Iteration  996: Cost   686.73
# Iteration  997: Cost   686.72
# Iteration  998: Cost   686.71
# Iteration  999: Cost   686.70
# b,w found by gradient descent: -0.00,[ 0.2   0.   -0.01 -0.07]
# prediction: 426.19, target value: 460
# prediction: 286.17, target value: 232
# prediction: 171.47, target value: 178

# %% [markdown]
# **Expected Result**:
# b,w found by gradient descent: -0.00,[ 0.2   0.   -0.01 -0.07]
# prediction: 426.19, target value: 460
# prediction: 286.17, target value: 232
# prediction: 171.47, target value: 178

# %%
# plot cost versus iteration  
fig, (ax1, ax2) = plt.subplots(1, 2, constrained_layout=True, figsize=(12, 4))
ax1.plot(J_hist[0:5])
ax2.plot(100 + np.arange(len(J_hist[100:])), J_hist[100:])
ax1.set_title("Cost vs. iteration");  ax2.set_title("Cost vs. iteration (tail)")
ax1.set_ylabel('Cost')             ;  ax2.set_ylabel('Cost') 
ax1.set_xlabel('iteration step')   ;  ax2.set_xlabel('iteration step') 
plt.show()

# %% [markdown]
# *These results are not inspiring*! Cost is still declining and our predictions are not very accurate. The next lab will explore how to improve on this.

# %% [markdown]
# <a name="toc_15456_6"></a>
# # 6 Congratulations!
# In this lab you:
# - Redeveloped the routines for linear regression, now with multiple variables.
# - Utilized NumPy `np.dot` to vectorize the implementations
